# %%
import json
from __future__ import print_function

try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib
import sys

#key=sys.argv[1]
#line=sys.argv[2]
key="a8063bd1-d70c-4d9b-9946-4c6fa10243b4"
bus_line = "B52"
##This url connects MTA API server to the file
url="http://bustime.mta.info/api/siri/vehicle-monitoring.json?key="+key+"&VehicleMonitoringDetailLevel=calls&LineRef="+ bus_line
##Opening JSON file and converting it to a dataframe
#print (url)
lib=urllib.urlopen(url)
data=lib.read().decode('utf-8')
data=json.loads(data)
#data.keys
##number of active buses
count_active_buses = len(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])
##Name of routes bus is currently active at
#route=data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['PublishedLineName']

#print('Bus Line :',route,'\nNumber of active buses :',count)
##Manipulating data for its current coordinates
#for i in range(count):
    #loc=data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']
    #print('Bus ',i,' is at latitude ',loc['Latitude'],' and longitude ',loc['Longitude'])
#data.keys()
# Out:
# [u'Siri']

# %%
data['Siri']
# Out:
# {u'ServiceDelivery': {u'ResponseTimestamp': u'2017-09-26T10:29:57.449-04:00',
#   u'SituationExchangeDelivery': [],
#   u'VehicleMonitoringDelivery': [{u'ResponseTimestamp': u'2017-09-26T10:29:57.449-04:00',
#     u'ValidUntil': u'2017-09-26T10:30:57.449-04:00',
#     u'VehicleActivity': [{u'MonitoredVehicleJourney': {u'Bearing': 186.63947,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday-SDon_E_FP_27240_B52-124',
#        u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#        u'DestinationRef': u'MTA_901463',
#        u'DirectionRef': u'1',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-26',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-SDon-059300_B52_124'},
#        u'JourneyPatternRef': u'MTA_B520048',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-26T10:29:58.449-04:00',
#         u'ExpectedDepartureTime': u'2017-09-26T10:29:58.449-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4675.5,
#           u'DistanceFromCall': 2.56,
#           u'PresentableDistance': u'at stop',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'GATES AV/FRANKLIN AV',
#         u'StopPointRef': u'MTA_304214',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-26T10:29:57.449-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4675.5,
#             u'DistanceFromCall': 2.56,
#             u'PresentableDistance': u'at stop',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'GATES AV/FRANKLIN AV',
#           u'StopPointRef': u'MTA_304214'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:30:25.900-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4864.08,
#             u'DistanceFromCall': 191.14,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'GATES AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307948'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:32:10.296-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5156.7,
#             u'DistanceFromCall': 483.76,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'GREENE AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307572'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:33:14.068-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5398.69,
#             u'DistanceFromCall': 725.75,
#             u'PresentableDistance': u'3 stops away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'GREENE AV/GRAND AV',
#           u'StopPointRef': u'MTA_307573'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:34:56.696-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5656.47,
#             u'DistanceFromCall': 983.53,
#             u'PresentableDistance': u'0.6 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'GREENE AV/WASHINGTON AV',
#           u'StopPointRef': u'MTA_307596'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:36:32.896-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5908.9,
#             u'DistanceFromCall': 1235.96,
#             u'PresentableDistance': u'0.8 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'GREENE AV/VANDERBILT AV',
#           u'StopPointRef': u'MTA_307575'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:37:37.640-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.28,
#             u'DistanceFromCall': 1402.34,
#             u'PresentableDistance': u'0.9 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'GREENE AV/ADELPHI ST',
#           u'StopPointRef': u'MTA_307576'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:38:41.240-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6239.48,
#             u'DistanceFromCall': 1566.54,
#             u'PresentableDistance': u'1.0 miles away',
#             u'StopsFromCall': 7}},
#           u'StopPointName': u'GREENE AV/CUMBERLAND ST',
#           u'StopPointRef': u'MTA_307577'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:40:42.240-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6482.4,
#             u'DistanceFromCall': 1809.45,
#             u'PresentableDistance': u'1.1 miles away',
#             u'StopsFromCall': 8}},
#           u'StopPointName': u'FULTON ST/S ELLIOTT PL',
#           u'StopPointRef': u'MTA_302427'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:41:50.644-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6639.55,
#             u'DistanceFromCall': 1966.61,
#             u'PresentableDistance': u'1.2 miles away',
#             u'StopsFromCall': 9}},
#           u'StopPointName': u'FULTON ST/FT GREENE PL',
#           u'StopPointRef': u'MTA_302428'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:43:19.644-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6938.8,
#             u'DistanceFromCall': 2265.86,
#             u'PresentableDistance': u'1.4 miles away',
#             u'StopsFromCall': 10}},
#           u'StopPointName': u'FULTON ST/HUDSON AV',
#           u'StopPointRef': u'MTA_302430'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:45:22.444-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7188.7,
#             u'DistanceFromCall': 2515.76,
#             u'PresentableDistance': u'1.6 miles away',
#             u'StopsFromCall': 11}},
#           u'StopPointName': u'FULTON ST/BOND ST',
#           u'StopPointRef': u'MTA_302431'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:47:00.148-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7394.01,
#             u'DistanceFromCall': 2721.06,
#             u'PresentableDistance': u'1.7 miles away',
#             u'StopsFromCall': 12}},
#           u'StopPointName': u'FULTON ST/DUFFIELD ST',
#           u'StopPointRef': u'MTA_307492'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:48:34.348-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7604.3,
#             u'DistanceFromCall': 2931.35,
#             u'PresentableDistance': u'1.8 miles away',
#             u'StopsFromCall': 13}},
#           u'StopPointName': u'FULTON ST/JAY ST',
#           u'StopPointRef': u'MTA_302433'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:51:45.700-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#             u'DistanceFromCall': 3256.79,
#             u'PresentableDistance': u'2.0 miles away',
#             u'StopsFromCall': 14}},
#           u'StopPointName': u'JORALEMON ST/COURT ST',
#           u'StopPointRef': u'MTA_302434'},
#          {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#             u'DistanceFromCall': 3386.71,
#             u'PresentableDistance': u'2.1 miles away',
#             u'StopsFromCall': 15}},
#           u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#           u'StopPointRef': u'MTA_306533'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:53:31.700-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#             u'DistanceFromCall': 3424.97,
#             u'PresentableDistance': u'2.1 miles away',
#             u'StopsFromCall': 16}},
#           u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#           u'StopPointRef': u'MTA_901463'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_504965',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.685487, u'Longitude': -73.956901},
#        u'VehicleRef': u'MTA NYCT_6495'},
#       u'RecordedAtTime': u'2017-09-26T10:29:25.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 158.57191,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday-SDon_E_FP_20040_B52-106',
#        u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#        u'DestinationRef': u'MTA_901463',
#        u'DirectionRef': u'1',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-26',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-SDon-058400_Q55_303'},
#        u'JourneyPatternRef': u'MTA_B520048',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-26T10:29:58.449-04:00',
#         u'ExpectedDepartureTime': u'2017-09-26T10:29:58.449-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6938.8,
#           u'DistanceFromCall': 14.14,
#           u'PresentableDistance': u'at stop',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'FULTON ST/HUDSON AV',
#         u'StopPointRef': u'MTA_302430',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-26T10:29:57.449-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6938.8,
#             u'DistanceFromCall': 14.14,
#             u'PresentableDistance': u'at stop',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'FULTON ST/HUDSON AV',
#           u'StopPointRef': u'MTA_302430'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:31:38.004-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7188.7,
#             u'DistanceFromCall': 264.04,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'FULTON ST/BOND ST',
#           u'StopPointRef': u'MTA_302431'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:33:15.708-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7394.01,
#             u'DistanceFromCall': 469.34,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'FULTON ST/DUFFIELD ST',
#           u'StopPointRef': u'MTA_307492'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:34:49.908-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7604.3,
#             u'DistanceFromCall': 679.63,
#             u'PresentableDistance': u'3 stops away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'FULTON ST/JAY ST',
#           u'StopPointRef': u'MTA_302433'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:38:01.260-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#             u'DistanceFromCall': 1005.07,
#             u'PresentableDistance': u'0.6 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'JORALEMON ST/COURT ST',
#           u'StopPointRef': u'MTA_302434'},
#          {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#             u'DistanceFromCall': 1134.99,
#             u'PresentableDistance': u'0.7 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#           u'StopPointRef': u'MTA_306533'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:39:47.260-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#             u'DistanceFromCall': 1173.25,
#             u'PresentableDistance': u'0.7 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#           u'StopPointRef': u'MTA_901463'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_504965',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.68855, u'Longitude': -73.980038},
#        u'VehicleRef': u'MTA NYCT_7262'},
#       u'RecordedAtTime': u'2017-09-26T10:29:31.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 171.48868,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday-SDon_E_FP_26340_B52-119',
#        u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#        u'DestinationRef': u'MTA_901463',
#        u'DirectionRef': u'1',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-26',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-SDon-057600_B52_119'},
#        u'JourneyPatternRef': u'MTA_B520048',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-26T10:29:58.449-04:00',
#         u'ExpectedDepartureTime': u'2017-09-26T10:29:58.449-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#           u'DistanceFromCall': 16.69,
#           u'PresentableDistance': u'at stop',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'JORALEMON ST/COURT ST',
#         u'StopPointRef': u'MTA_302434',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-26T10:29:57.449-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#             u'DistanceFromCall': 16.69,
#             u'PresentableDistance': u'at stop',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'JORALEMON ST/COURT ST',
#           u'StopPointRef': u'MTA_302434'},
#          {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#             u'DistanceFromCall': 146.6,
#             u'PresentableDistance': u'approaching',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#           u'StopPointRef': u'MTA_306533'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:31:23.812-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#             u'DistanceFromCall': 184.86,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#           u'StopPointRef': u'MTA_901463'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_504965',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.692475, u'Longitude': -73.990517},
#        u'VehicleRef': u'MTA NYCT_3988'},
#       u'RecordedAtTime': u'2017-09-26T10:29:28.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 281.30994,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday-SDon_E_FP_18300_B26-3',
#        u'DestinationName': u'RIDGEWOOD TERM via GATES',
#        u'DestinationRef': u'MTA_801117',
#        u'DirectionRef': u'0',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-26',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-SDon-060700_B52_113'},
#        u'JourneyPatternRef': u'MTA_B520040',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-26T10:30:02.736-04:00',
#         u'ExpectedDepartureTime': u'2017-09-26T10:30:02.736-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3827.24,
#           u'DistanceFromCall': 40.16,
#           u'PresentableDistance': u'approaching',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'GATES AV/FRANKLIN AV',
#         u'StopPointRef': u'MTA_307674',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-26T10:30:02.736-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3827.24,
#             u'DistanceFromCall': 40.16,
#             u'PresentableDistance': u'approaching',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'GATES AV/FRANKLIN AV',
#           u'StopPointRef': u'MTA_307674'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:31:19.604-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4010.77,
#             u'DistanceFromCall': 223.7,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'GATES AV/BEDFORD AV',
#           u'StopPointRef': u'MTA_307675'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:32:21.869-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4274.94,
#             u'DistanceFromCall': 487.86,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'GATES AV/NOSTRAND AV',
#           u'StopPointRef': u'MTA_307676'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:34:12.269-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4600.33,
#             u'DistanceFromCall': 813.25,
#             u'PresentableDistance': u'0.5 miles away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'GATES AV/MARCY AV',
#           u'StopPointRef': u'MTA_307677'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:35:35.069-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4849.89,
#             u'DistanceFromCall': 1062.81,
#             u'PresentableDistance': u'0.7 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'GATES AV/TOMPKINS AV',
#           u'StopPointRef': u'MTA_307678'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:36:50.269-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5087.05,
#             u'DistanceFromCall': 1299.97,
#             u'PresentableDistance': u'0.8 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'GATES AV/THROOP AV',
#           u'StopPointRef': u'MTA_307679'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:38:03.323-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5326.1,
#             u'DistanceFromCall': 1539.02,
#             u'PresentableDistance': u'1.0 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#           u'StopPointRef': u'MTA_307680'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:39:21.850-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5574.85,
#             u'DistanceFromCall': 1787.77,
#             u'PresentableDistance': u'1.1 miles away',
#             u'StopsFromCall': 7}},
#           u'StopPointName': u'GATES AV/LEWIS AV',
#           u'StopPointRef': u'MTA_307681'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:40:41.650-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5826.46,
#             u'DistanceFromCall': 2039.38,
#             u'PresentableDistance': u'1.3 miles away',
#             u'StopsFromCall': 8}},
#           u'StopPointName': u'GATES AV/STUYVESANT AV',
#           u'StopPointRef': u'MTA_307682'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:42:18.219-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.85,
#             u'DistanceFromCall': 2288.77,
#             u'PresentableDistance': u'1.4 miles away',
#             u'StopsFromCall': 9}},
#           u'StopPointName': u'GATES AV/MALCOLM X BL',
#           u'StopPointRef': u'MTA_307683'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:43:27.583-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6321.91,
#             u'DistanceFromCall': 2534.83,
#             u'PresentableDistance': u'1.6 miles away',
#             u'StopsFromCall': 10}},
#           u'StopPointName': u'GATES AV/PATCHEN AV',
#           u'StopPointRef': u'MTA_307684'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:44:28.216-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6555.96,
#             u'DistanceFromCall': 2768.88,
#             u'PresentableDistance': u'1.7 miles away',
#             u'StopsFromCall': 11}},
#           u'StopPointName': u'GATES AV/RALPH AV',
#           u'StopPointRef': u'MTA_307901'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:45:29.052-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6717.8,
#             u'DistanceFromCall': 2930.72,
#             u'PresentableDistance': u'1.8 miles away',
#             u'StopsFromCall': 12}},
#           u'StopPointName': u'GATES AV/BROADWAY',
#           u'StopPointRef': u'MTA_307686'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:47:07.727-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6962.31,
#             u'DistanceFromCall': 3175.23,
#             u'PresentableDistance': u'2.0 miles away',
#             u'StopsFromCall': 13}},
#           u'StopPointName': u'GATES AV/BUSHWICK AV',
#           u'StopPointRef': u'MTA_307687'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:47:55.712-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7131.71,
#             u'DistanceFromCall': 3344.63,
#             u'PresentableDistance': u'2.1 miles away',
#             u'StopsFromCall': 14}},
#           u'StopPointName': u'GATES AV/EVERGREEN AV',
#           u'StopPointRef': u'MTA_307688'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:49:03.712-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
#             u'DistanceFromCall': 3586.51,
#             u'PresentableDistance': u'2.2 miles away',
#             u'StopsFromCall': 15}},
#           u'StopPointName': u'GATES AV/CENTRAL AV',
#           u'StopPointRef': u'MTA_307689'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:50:18.112-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7576.02,
#             u'DistanceFromCall': 3788.94,
#             u'PresentableDistance': u'2.4 miles away',
#             u'StopsFromCall': 16}},
#           u'StopPointName': u'GATES AV/WILSON AV',
#           u'StopPointRef': u'MTA_307690'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:51:23.712-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7782.09,
#             u'DistanceFromCall': 3995.01,
#             u'PresentableDistance': u'2.5 miles away',
#             u'StopsFromCall': 17}},
#           u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#           u'StopPointRef': u'MTA_307691'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:52:42.628-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#             u'DistanceFromCall': 4294.29,
#             u'PresentableDistance': u'2.7 miles away',
#             u'StopsFromCall': 18}},
#           u'StopPointName': u'PALMETTO ST/IRVING AV',
#           u'StopPointRef': u'MTA_304415'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:53:19.228-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#             u'DistanceFromCall': 4444.2,
#             u'PresentableDistance': u'2.8 miles away',
#             u'StopsFromCall': 19}},
#           u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#           u'StopPointRef': u'MTA_801117'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_307175',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.685556, u'Longitude': -73.956558},
#        u'VehicleRef': u'MTA NYCT_6501'},
#       u'RecordedAtTime': u'2017-09-26T10:29:53.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 186.55295,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday-SDon_E_FP_21060_B52-107',
#        u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#        u'DestinationRef': u'MTA_901463',
#        u'DirectionRef': u'1',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-26',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-SDon-061000_B52_103'},
#        u'JourneyPatternRef': u'MTA_B520048',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-26T10:30:13.919-04:00',
#         u'ExpectedDepartureTime': u'2017-09-26T10:30:13.919-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3177.93,
#           u'DistanceFromCall': 56.8,
#           u'PresentableDistance': u'approaching',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#         u'StopPointRef': u'MTA_306530',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-26T10:30:13.919-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3177.93,
#             u'DistanceFromCall': 56.8,
#             u'PresentableDistance': u'approaching',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#           u'StopPointRef': u'MTA_306530'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:31:18.919-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3373.19,
#             u'DistanceFromCall': 252.07,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'GATES AV/THROOP AV',
#           u'StopPointRef': u'MTA_304209'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:33:08.119-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3659.93,
#             u'DistanceFromCall': 538.8,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'GATES AV/TOMPKINS AV',
#           u'StopPointRef': u'MTA_304210'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:34:43.998-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3902.63,
#             u'DistanceFromCall': 781.5,
#             u'PresentableDistance': u'3 stops away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'GATES AV/MARCY AV',
#           u'StopPointRef': u'MTA_304211'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:36:38.964-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4182.76,
#             u'DistanceFromCall': 1061.63,
#             u'PresentableDistance': u'0.7 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'GATES AV/NOSTRAND AV',
#           u'StopPointRef': u'MTA_304212'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:38:20.173-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4496.51,
#             u'DistanceFromCall': 1375.39,
#             u'PresentableDistance': u'0.9 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'GATES AV/BEDFORD AV',
#           u'StopPointRef': u'MTA_304213'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:39:33.319-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4675.5,
#             u'DistanceFromCall': 1554.37,
#             u'PresentableDistance': u'1.0 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'GATES AV/FRANKLIN AV',
#           u'StopPointRef': u'MTA_304214'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:40:33.175-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4864.08,
#             u'DistanceFromCall': 1742.95,
#             u'PresentableDistance': u'1.1 miles away',
#             u'StopsFromCall': 7}},
#           u'StopPointName': u'GATES AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307948'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:42:17.571-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5156.7,
#             u'DistanceFromCall': 2035.57,
#             u'PresentableDistance': u'1.3 miles away',
#             u'StopsFromCall': 8}},
#           u'StopPointName': u'GREENE AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307572'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:43:21.343-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5398.69,
#             u'DistanceFromCall': 2277.56,
#             u'PresentableDistance': u'1.4 miles away',
#             u'StopsFromCall': 9}},
#           u'StopPointName': u'GREENE AV/GRAND AV',
#           u'StopPointRef': u'MTA_307573'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:45:03.971-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5656.47,
#             u'DistanceFromCall': 2535.34,
#             u'PresentableDistance': u'1.6 miles away',
#             u'StopsFromCall': 10}},
#           u'StopPointName': u'GREENE AV/WASHINGTON AV',
#           u'StopPointRef': u'MTA_307596'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:46:40.171-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5908.9,
#             u'DistanceFromCall': 2787.78,
#             u'PresentableDistance': u'1.7 miles away',
#             u'StopsFromCall': 11}},
#           u'StopPointName': u'GREENE AV/VANDERBILT AV',
#           u'StopPointRef': u'MTA_307575'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:47:44.915-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.28,
#             u'DistanceFromCall': 2954.15,
#             u'PresentableDistance': u'1.8 miles away',
#             u'StopsFromCall': 12}},
#           u'StopPointName': u'GREENE AV/ADELPHI ST',
#           u'StopPointRef': u'MTA_307576'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:48:48.515-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6239.48,
#             u'DistanceFromCall': 3118.35,
#             u'PresentableDistance': u'1.9 miles away',
#             u'StopsFromCall': 13}},
#           u'StopPointName': u'GREENE AV/CUMBERLAND ST',
#           u'StopPointRef': u'MTA_307577'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:50:49.515-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6482.4,
#             u'DistanceFromCall': 3361.27,
#             u'PresentableDistance': u'2.1 miles away',
#             u'StopsFromCall': 14}},
#           u'StopPointName': u'FULTON ST/S ELLIOTT PL',
#           u'StopPointRef': u'MTA_302427'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:51:57.919-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6639.55,
#             u'DistanceFromCall': 3518.42,
#             u'PresentableDistance': u'2.2 miles away',
#             u'StopsFromCall': 15}},
#           u'StopPointName': u'FULTON ST/FT GREENE PL',
#           u'StopPointRef': u'MTA_302428'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:53:26.919-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6938.8,
#             u'DistanceFromCall': 3817.68,
#             u'PresentableDistance': u'2.4 miles away',
#             u'StopsFromCall': 16}},
#           u'StopPointName': u'FULTON ST/HUDSON AV',
#           u'StopPointRef': u'MTA_302430'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:55:29.719-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7188.7,
#             u'DistanceFromCall': 4067.58,
#             u'PresentableDistance': u'2.5 miles away',
#             u'StopsFromCall': 17}},
#           u'StopPointName': u'FULTON ST/BOND ST',
#           u'StopPointRef': u'MTA_302431'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:57:07.423-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7394.01,
#             u'DistanceFromCall': 4272.88,
#             u'PresentableDistance': u'2.7 miles away',
#             u'StopsFromCall': 18}},
#           u'StopPointName': u'FULTON ST/DUFFIELD ST',
#           u'StopPointRef': u'MTA_307492'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:58:41.623-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7604.3,
#             u'DistanceFromCall': 4483.17,
#             u'PresentableDistance': u'2.8 miles away',
#             u'StopsFromCall': 19}},
#           u'StopPointName': u'FULTON ST/JAY ST',
#           u'StopPointRef': u'MTA_302433'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:01:52.975-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#             u'DistanceFromCall': 4808.61,
#             u'PresentableDistance': u'3.0 miles away',
#             u'StopsFromCall': 20}},
#           u'StopPointName': u'JORALEMON ST/COURT ST',
#           u'StopPointRef': u'MTA_302434'},
#          {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#             u'DistanceFromCall': 4938.52,
#             u'PresentableDistance': u'3.1 miles away',
#             u'StopsFromCall': 21}},
#           u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#           u'StopPointRef': u'MTA_306533'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:03:38.975-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#             u'DistanceFromCall': 4976.78,
#             u'PresentableDistance': u'3.1 miles away',
#             u'StopsFromCall': 22}},
#           u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#           u'StopPointRef': u'MTA_901463'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_504965',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.687584, u'Longitude': -73.938706},
#        u'VehicleRef': u'MTA NYCT_7282'},
#       u'RecordedAtTime': u'2017-09-26T10:29:55.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 186.53427,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday-SDon_E_FP_15300_B52-102',
#        u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#        u'DestinationRef': u'MTA_901463',
#        u'DirectionRef': u'1',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-26',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-SDon-060100_B52_115'},
#        u'JourneyPatternRef': u'MTA_B520048',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-26T10:30:10.570-04:00',
#         u'ExpectedDepartureTime': u'2017-09-26T10:30:10.570-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4496.51,
#           u'DistanceFromCall': 63.77,
#           u'PresentableDistance': u'approaching',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'GATES AV/BEDFORD AV',
#         u'StopPointRef': u'MTA_304213',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-26T10:30:10.570-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4496.51,
#             u'DistanceFromCall': 63.77,
#             u'PresentableDistance': u'approaching',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'GATES AV/BEDFORD AV',
#           u'StopPointRef': u'MTA_304213'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:31:23.716-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4675.5,
#             u'DistanceFromCall': 242.76,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'GATES AV/FRANKLIN AV',
#           u'StopPointRef': u'MTA_304214'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:32:23.572-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4864.08,
#             u'DistanceFromCall': 431.34,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'GATES AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307948'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:34:07.968-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5156.7,
#             u'DistanceFromCall': 723.96,
#             u'PresentableDistance': u'3 stops away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'GREENE AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307572'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:35:11.740-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5398.69,
#             u'DistanceFromCall': 965.95,
#             u'PresentableDistance': u'0.6 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'GREENE AV/GRAND AV',
#           u'StopPointRef': u'MTA_307573'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:36:54.368-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5656.47,
#             u'DistanceFromCall': 1223.73,
#             u'PresentableDistance': u'0.8 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'GREENE AV/WASHINGTON AV',
#           u'StopPointRef': u'MTA_307596'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:38:30.568-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5908.9,
#             u'DistanceFromCall': 1476.16,
#             u'PresentableDistance': u'0.9 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'GREENE AV/VANDERBILT AV',
#           u'StopPointRef': u'MTA_307575'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:39:35.312-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.28,
#             u'DistanceFromCall': 1642.54,
#             u'PresentableDistance': u'1.0 miles away',
#             u'StopsFromCall': 7}},
#           u'StopPointName': u'GREENE AV/ADELPHI ST',
#           u'StopPointRef': u'MTA_307576'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:40:38.912-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6239.48,
#             u'DistanceFromCall': 1806.74,
#             u'PresentableDistance': u'1.1 miles away',
#             u'StopsFromCall': 8}},
#           u'StopPointName': u'GREENE AV/CUMBERLAND ST',
#           u'StopPointRef': u'MTA_307577'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:42:39.912-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6482.4,
#             u'DistanceFromCall': 2049.65,
#             u'PresentableDistance': u'1.3 miles away',
#             u'StopsFromCall': 9}},
#           u'StopPointName': u'FULTON ST/S ELLIOTT PL',
#           u'StopPointRef': u'MTA_302427'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:43:48.316-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6639.55,
#             u'DistanceFromCall': 2206.81,
#             u'PresentableDistance': u'1.4 miles away',
#             u'StopsFromCall': 10}},
#           u'StopPointName': u'FULTON ST/FT GREENE PL',
#           u'StopPointRef': u'MTA_302428'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:45:17.316-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6938.8,
#             u'DistanceFromCall': 2506.06,
#             u'PresentableDistance': u'1.6 miles away',
#             u'StopsFromCall': 11}},
#           u'StopPointName': u'FULTON ST/HUDSON AV',
#           u'StopPointRef': u'MTA_302430'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:47:20.116-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7188.7,
#             u'DistanceFromCall': 2755.96,
#             u'PresentableDistance': u'1.7 miles away',
#             u'StopsFromCall': 12}},
#           u'StopPointName': u'FULTON ST/BOND ST',
#           u'StopPointRef': u'MTA_302431'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:48:57.820-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7394.01,
#             u'DistanceFromCall': 2961.26,
#             u'PresentableDistance': u'1.8 miles away',
#             u'StopsFromCall': 13}},
#           u'StopPointName': u'FULTON ST/DUFFIELD ST',
#           u'StopPointRef': u'MTA_307492'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:50:32.020-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7604.3,
#             u'DistanceFromCall': 3171.55,
#             u'PresentableDistance': u'2.0 miles away',
#             u'StopsFromCall': 14}},
#           u'StopPointName': u'FULTON ST/JAY ST',
#           u'StopPointRef': u'MTA_302433'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:53:43.372-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#             u'DistanceFromCall': 3496.99,
#             u'PresentableDistance': u'2.2 miles away',
#             u'StopsFromCall': 15}},
#           u'StopPointName': u'JORALEMON ST/COURT ST',
#           u'StopPointRef': u'MTA_302434'},
#          {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#             u'DistanceFromCall': 3626.91,
#             u'PresentableDistance': u'2.3 miles away',
#             u'StopsFromCall': 16}},
#           u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#           u'StopPointRef': u'MTA_306533'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:55:29.372-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#             u'DistanceFromCall': 3665.17,
#             u'PresentableDistance': u'2.3 miles away',
#             u'StopsFromCall': 17}},
#           u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#           u'StopPointRef': u'MTA_901463'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_504965',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.685814, u'Longitude': -73.954085},
#        u'VehicleRef': u'MTA NYCT_4518'},
#       u'RecordedAtTime': u'2017-09-26T10:29:50.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 45.911446,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday-SDon_E_FP_23520_Q55-308',
#        u'DestinationName': u'RIDGEWOOD TERM via GATES',
#        u'DestinationRef': u'MTA_801117',
#        u'DirectionRef': u'0',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-26',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-SDon-059300_Q55_308'},
#        u'JourneyPatternRef': u'MTA_B520040',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-26T10:30:04.891-04:00',
#         u'ExpectedDepartureTime': u'2017-09-26T10:30:04.891-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6962.31,
#           u'DistanceFromCall': 81.5,
#           u'PresentableDistance': u'approaching',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'GATES AV/BUSHWICK AV',
#         u'StopPointRef': u'MTA_307687',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-26T10:30:04.891-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6962.31,
#             u'DistanceFromCall': 81.5,
#             u'PresentableDistance': u'approaching',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'GATES AV/BUSHWICK AV',
#           u'StopPointRef': u'MTA_307687'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:30:49.794-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7131.71,
#             u'DistanceFromCall': 250.9,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'GATES AV/EVERGREEN AV',
#           u'StopPointRef': u'MTA_307688'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:31:57.794-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
#             u'DistanceFromCall': 492.78,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'GATES AV/CENTRAL AV',
#           u'StopPointRef': u'MTA_307689'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:33:12.194-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7576.02,
#             u'DistanceFromCall': 695.21,
#             u'PresentableDistance': u'3 stops away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'GATES AV/WILSON AV',
#           u'StopPointRef': u'MTA_307690'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:34:17.794-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7782.09,
#             u'DistanceFromCall': 901.29,
#             u'PresentableDistance': u'0.6 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#           u'StopPointRef': u'MTA_307691'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:35:36.710-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#             u'DistanceFromCall': 1200.57,
#             u'PresentableDistance': u'0.7 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'PALMETTO ST/IRVING AV',
#           u'StopPointRef': u'MTA_304415'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:36:13.310-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#             u'DistanceFromCall': 1350.47,
#             u'PresentableDistance': u'0.8 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#           u'StopPointRef': u'MTA_801117'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_307175',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.690569, u'Longitude': -73.921005},
#        u'VehicleRef': u'MTA NYCT_3968'},
#       u'RecordedAtTime': u'2017-09-26T10:29:32.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 45.522087,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday-SDon_E_FP_17400_B52-104',
#        u'DestinationName': u'RIDGEWOOD TERM via GATES',
#        u'DestinationRef': u'MTA_801117',
#        u'DirectionRef': u'0',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-26',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-SDon-058600_B52_104'},
#        u'JourneyPatternRef': u'MTA_B520040',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-26T10:30:03.674-04:00',
#         u'ExpectedDepartureTime': u'2017-09-26T10:30:03.674-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
#           u'DistanceFromCall': 98.44,
#           u'PresentableDistance': u'approaching',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'GATES AV/CENTRAL AV',
#         u'StopPointRef': u'MTA_307689',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-26T10:30:03.674-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
#             u'DistanceFromCall': 98.44,
#             u'PresentableDistance': u'approaching',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'GATES AV/CENTRAL AV',
#           u'StopPointRef': u'MTA_307689'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:31:18.074-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7576.02,
#             u'DistanceFromCall': 300.87,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'GATES AV/WILSON AV',
#           u'StopPointRef': u'MTA_307690'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:32:23.674-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7782.09,
#             u'DistanceFromCall': 506.94,
#             u'PresentableDistance': u'2 stops away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#           u'StopPointRef': u'MTA_307691'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:33:42.590-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#             u'DistanceFromCall': 806.22,
#             u'PresentableDistance': u'0.5 miles away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'PALMETTO ST/IRVING AV',
#           u'StopPointRef': u'MTA_304415'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:34:19.190-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#             u'DistanceFromCall': 956.13,
#             u'PresentableDistance': u'0.6 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#           u'StopPointRef': u'MTA_801117'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_307175',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
# ...
#           u'StopPointRef': u'MTA_307690'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:56:34.325-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7782.09,
#             u'DistanceFromCall': 5162.41,
#             u'PresentableDistance': u'3.2 miles away',
#             u'StopsFromCall': 21}},
#           u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#           u'StopPointRef': u'MTA_307691'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:57:53.241-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#             u'DistanceFromCall': 5461.69,
#             u'PresentableDistance': u'3.4 miles away',
#             u'StopsFromCall': 22}},
#           u'StopPointName': u'PALMETTO ST/IRVING AV',
#           u'StopPointRef': u'MTA_304415'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:58:29.841-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#             u'DistanceFromCall': 5611.59,
#             u'PresentableDistance': u'3.5 miles away',
#             u'StopsFromCall': 23}},
#           u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#           u'StopPointRef': u'MTA_801117'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_307175',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.68648, u'Longitude': -73.96781},
#        u'VehicleRef': u'MTA NYCT_4520'},
#       u'RecordedAtTime': u'2017-09-26T10:29:45.000-04:00'},
#      {u'MonitoredVehicleJourney': {u'Bearing': 357.6435,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday-SDon_E_FP_25440_B52-116',
#        u'DestinationName': u'RIDGEWOOD TERM via GATES',
#        u'DestinationRef': u'MTA_801117',
#        u'DirectionRef': u'0',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-26',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-SDon-062800_B52_116'},
#        u'JourneyPatternRef': u'MTA_B520040',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-26T10:32:01.325-04:00',
#         u'ExpectedDepartureTime': u'2017-09-26T10:32:01.325-04:00',
#         u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 598.44,
#           u'DistanceFromCall': 422.9,
#           u'PresentableDistance': u'< 1 stop away',
#           u'StopsFromCall': 0}},
#         u'StopPointName': u'ADAMS ST/BKLYN SUPREME CRT',
#         u'StopPointRef': u'MTA_307460',
#         u'VisitNumber': 1},
#        u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-26T10:32:01.325-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 598.44,
#             u'DistanceFromCall': 422.9,
#             u'PresentableDistance': u'< 1 stop away',
#             u'StopsFromCall': 0}},
#           u'StopPointName': u'ADAMS ST/BKLYN SUPREME CRT',
#           u'StopPointRef': u'MTA_307460'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:34:16.394-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 797.4,
#             u'DistanceFromCall': 621.86,
#             u'PresentableDistance': u'1 stop away',
#             u'StopsFromCall': 1}},
#           u'StopPointName': u'FULTON ST/SMITH ST',
#           u'StopPointRef': u'MTA_302945'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:35:37.770-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 986.57,
#             u'DistanceFromCall': 811.03,
#             u'PresentableDistance': u'0.5 miles away',
#             u'StopsFromCall': 2}},
#           u'StopPointName': u'FULTON ST/HOYT ST',
#           u'StopPointRef': u'MTA_307491'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:37:04.370-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1220.03,
#             u'DistanceFromCall': 1044.49,
#             u'PresentableDistance': u'0.6 miles away',
#             u'StopsFromCall': 3}},
#           u'StopPointName': u'FULTON ST/BOND ST',
#           u'StopPointRef': u'MTA_302947'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:38:23.963-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1393.71,
#             u'DistanceFromCall': 1218.17,
#             u'PresentableDistance': u'0.8 miles away',
#             u'StopsFromCall': 4}},
#           u'StopPointName': u'FULTON ST/FLATBUSH AV EXT',
#           u'StopPointRef': u'MTA_302948'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:40:15.204-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1683.32,
#             u'DistanceFromCall': 1507.78,
#             u'PresentableDistance': u'0.9 miles away',
#             u'StopsFromCall': 5}},
#           u'StopPointName': u'FULTON ST/ASHLAND PL',
#           u'StopPointRef': u'MTA_303017'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:40:53.618-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1831.55,
#             u'DistanceFromCall': 1656.01,
#             u'PresentableDistance': u'1.0 miles away',
#             u'StopsFromCall': 6}},
#           u'StopPointName': u'FULTON ST/LAFAYETTE AV',
#           u'StopPointRef': u'MTA_302368'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:42:53.142-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2085.33,
#             u'DistanceFromCall': 1909.79,
#             u'PresentableDistance': u'1.2 miles away',
#             u'StopsFromCall': 7}},
#           u'StopPointName': u'FULTON ST/S PORTLAND AV',
#           u'StopPointRef': u'MTA_302369'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:43:44.525-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2214.42,
#             u'DistanceFromCall': 2038.88,
#             u'PresentableDistance': u'1.3 miles away',
#             u'StopsFromCall': 8}},
#           u'StopPointName': u'GREENE AV/FULTON ST',
#           u'StopPointRef': u'MTA_307547'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:44:48.525-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2427.7,
#             u'DistanceFromCall': 2252.16,
#             u'PresentableDistance': u'1.4 miles away',
#             u'StopsFromCall': 9}},
#           u'StopPointName': u'GREENE AV/ADELPHI ST',
#           u'StopPointRef': u'MTA_307548'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:45:49.325-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2599.71,
#             u'DistanceFromCall': 2424.17,
#             u'PresentableDistance': u'1.5 miles away',
#             u'StopsFromCall': 10}},
#           u'StopPointName': u'GREENE AV/VANDERBILT AV',
#           u'StopPointRef': u'MTA_307549'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:47:07.269-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2849.35,
#             u'DistanceFromCall': 2673.81,
#             u'PresentableDistance': u'1.7 miles away',
#             u'StopsFromCall': 11}},
#           u'StopPointName': u'GREENE AV/WASHINGTON AV',
#           u'StopPointRef': u'MTA_307550'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:48:13.669-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3107.79,
#             u'DistanceFromCall': 2932.25,
#             u'PresentableDistance': u'1.8 miles away',
#             u'StopsFromCall': 12}},
#           u'StopPointName': u'GREENE AV/GRAND AV',
#           u'StopPointRef': u'MTA_307551'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:49:19.069-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3346.41,
#             u'DistanceFromCall': 3170.87,
#             u'PresentableDistance': u'2.0 miles away',
#             u'StopsFromCall': 13}},
#           u'StopPointName': u'GREENE AV/CLASSON AV',
#           u'StopPointRef': u'MTA_307552'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:50:23.869-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3579.59,
#             u'DistanceFromCall': 3404.05,
#             u'PresentableDistance': u'2.1 miles away',
#             u'StopsFromCall': 14}},
#           u'StopPointName': u'FRANKLIN AV/GREENE AV',
#           u'StopPointRef': u'MTA_307553'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:51:23.910-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3827.24,
#             u'DistanceFromCall': 3651.7,
#             u'PresentableDistance': u'2.3 miles away',
#             u'StopsFromCall': 15}},
#           u'StopPointName': u'GATES AV/FRANKLIN AV',
#           u'StopPointRef': u'MTA_307674'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:52:40.778-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4010.77,
#             u'DistanceFromCall': 3835.23,
#             u'PresentableDistance': u'2.4 miles away',
#             u'StopsFromCall': 16}},
#           u'StopPointName': u'GATES AV/BEDFORD AV',
#           u'StopPointRef': u'MTA_307675'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:53:43.043-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4274.94,
#             u'DistanceFromCall': 4099.4,
#             u'PresentableDistance': u'2.5 miles away',
#             u'StopsFromCall': 17}},
#           u'StopPointName': u'GATES AV/NOSTRAND AV',
#           u'StopPointRef': u'MTA_307676'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:55:33.443-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4600.33,
#             u'DistanceFromCall': 4424.79,
#             u'PresentableDistance': u'2.7 miles away',
#             u'StopsFromCall': 18}},
#           u'StopPointName': u'GATES AV/MARCY AV',
#           u'StopPointRef': u'MTA_307677'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:56:56.243-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4849.89,
#             u'DistanceFromCall': 4674.35,
#             u'PresentableDistance': u'2.9 miles away',
#             u'StopsFromCall': 19}},
#           u'StopPointName': u'GATES AV/TOMPKINS AV',
#           u'StopPointRef': u'MTA_307678'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:58:11.443-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5087.05,
#             u'DistanceFromCall': 4911.51,
#             u'PresentableDistance': u'3.1 miles away',
#             u'StopsFromCall': 20}},
#           u'StopPointName': u'GATES AV/THROOP AV',
#           u'StopPointRef': u'MTA_307679'},
#          {u'ExpectedArrivalTime': u'2017-09-26T10:59:24.497-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5326.1,
#             u'DistanceFromCall': 5150.56,
#             u'PresentableDistance': u'3.2 miles away',
#             u'StopsFromCall': 21}},
#           u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#           u'StopPointRef': u'MTA_307680'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:00:43.024-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5574.85,
#             u'DistanceFromCall': 5399.31,
#             u'PresentableDistance': u'3.4 miles away',
#             u'StopsFromCall': 22}},
#           u'StopPointName': u'GATES AV/LEWIS AV',
#           u'StopPointRef': u'MTA_307681'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:02:02.824-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5826.46,
#             u'DistanceFromCall': 5650.92,
#             u'PresentableDistance': u'3.5 miles away',
#             u'StopsFromCall': 23}},
#           u'StopPointName': u'GATES AV/STUYVESANT AV',
#           u'StopPointRef': u'MTA_307682'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:03:39.393-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.85,
#             u'DistanceFromCall': 5900.31,
#             u'PresentableDistance': u'3.7 miles away',
#             u'StopsFromCall': 24}},
#           u'StopPointName': u'GATES AV/MALCOLM X BL',
#           u'StopPointRef': u'MTA_307683'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:04:48.757-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6321.91,
#             u'DistanceFromCall': 6146.37,
#             u'PresentableDistance': u'3.8 miles away',
#             u'StopsFromCall': 25}},
#           u'StopPointName': u'GATES AV/PATCHEN AV',
#           u'StopPointRef': u'MTA_307684'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:05:49.390-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6555.96,
#             u'DistanceFromCall': 6380.42,
#             u'PresentableDistance': u'4.0 miles away',
#             u'StopsFromCall': 26}},
#           u'StopPointName': u'GATES AV/RALPH AV',
#           u'StopPointRef': u'MTA_307901'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:06:50.226-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6717.8,
#             u'DistanceFromCall': 6542.26,
#             u'PresentableDistance': u'4.1 miles away',
#             u'StopsFromCall': 27}},
#           u'StopPointName': u'GATES AV/BROADWAY',
#           u'StopPointRef': u'MTA_307686'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:08:28.901-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6962.31,
#             u'DistanceFromCall': 6786.77,
#             u'PresentableDistance': u'4.2 miles away',
#             u'StopsFromCall': 28}},
#           u'StopPointName': u'GATES AV/BUSHWICK AV',
#           u'StopPointRef': u'MTA_307687'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:09:13.804-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7131.71,
#             u'DistanceFromCall': 6956.17,
#             u'PresentableDistance': u'4.3 miles away',
#             u'StopsFromCall': 29}},
#           u'StopPointName': u'GATES AV/EVERGREEN AV',
#           u'StopPointRef': u'MTA_307688'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:10:21.804-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
#             u'DistanceFromCall': 7198.05,
#             u'PresentableDistance': u'4.5 miles away',
#             u'StopsFromCall': 30}},
#           u'StopPointName': u'GATES AV/CENTRAL AV',
#           u'StopPointRef': u'MTA_307689'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:11:36.204-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7576.02,
#             u'DistanceFromCall': 7400.48,
#             u'PresentableDistance': u'4.6 miles away',
#             u'StopsFromCall': 31}},
#           u'StopPointName': u'GATES AV/WILSON AV',
#           u'StopPointRef': u'MTA_307690'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:12:41.804-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7782.09,
#             u'DistanceFromCall': 7606.55,
#             u'PresentableDistance': u'4.7 miles away',
#             u'StopsFromCall': 32}},
#           u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#           u'StopPointRef': u'MTA_307691'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:14:00.720-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#             u'DistanceFromCall': 7905.83,
#             u'PresentableDistance': u'4.9 miles away',
#             u'StopsFromCall': 33}},
#           u'StopPointName': u'PALMETTO ST/IRVING AV',
#           u'StopPointRef': u'MTA_304415'},
#          {u'ExpectedArrivalTime': u'2017-09-26T11:14:37.320-04:00',
#           u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#             u'DistanceFromCall': 8055.74,
#             u'PresentableDistance': u'5.0 miles away',
#             u'StopsFromCall': 34}},
#           u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#           u'StopPointRef': u'MTA_801117'}]},
#        u'OperatorRef': u'MTA NYCT',
#        u'OriginRef': u'MTA_307175',
#        u'ProgressRate': u'normalProgress',
#        u'PublishedLineName': u'B52',
#        u'SituationRef': [],
#        u'VehicleLocation': {u'Latitude': 40.696122, u'Longitude': -73.989298},
#        u'VehicleRef': u'MTA NYCT_3970'},
#       u'RecordedAtTime': u'2017-09-26T10:29:35.000-04:00'}]}]}}

# %%
with open('blah.json', 'w') as f:
    json.dump(data, f)

# %%
count_active_buses = len(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])
##Name of routes bus is currently active at
#route=data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['PublishedLineName']

print('Bus Line :',bus_line, '\nNumber of active buses:',count_active_buses)
##Manipulating data for its current coordinates
for i in range(count_active_buses):
    location=data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']
    print('Bus ',i,' is at latitude ',location['Latitude'],' and longitude ',location['Longitude'])
# Out:
# Bus Line : B52
# Number of active buses: 15
# Bus  0  is at latitude  40.687045  and longitude  -73.962919
# Bus  1  is at latitude  40.689468  and longitude  -73.922254
# Bus  2  is at latitude  40.693701  and longitude  -73.917934
# Bus  3  is at latitude  40.687517  and longitude  -73.956945
# Bus  4  is at latitude  40.693462  and longitude  -73.990535
# Bus  5  is at latitude  40.699127  and longitude  -73.911431
# Bus  6  is at latitude  40.689135  and longitude  -73.981529
# Bus  7  is at latitude  40.689436  and longitude  -73.922539
# Bus  8  is at latitude  40.686902  and longitude  -73.944631
# Bus  9  is at latitude  40.686214  and longitude  -73.950597
# Bus  10  is at latitude  40.685821  and longitude  -73.954026
# Bus  11  is at latitude  40.688678  and longitude  -73.929184
# Bus  12  is at latitude  40.688565  and longitude  -73.980078
# Bus  13  is at latitude  40.685821  and longitude  -73.959397
# Bus  14  is at latitude  40.688915  and longitude  -73.980963
