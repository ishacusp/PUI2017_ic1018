# %%
from __future__ import print_function
__author__ = "Isha Chaturvedi, CUSP NYU 2017"

# %% [markdown]
# Create a reproducible research chunk of code¶
# That means we want the reader to be able to reproduce every step of the work we do.
# If our work includes the use of stochastic processes and random variables that gets tricky: how do we assure the random draw gives the same number to the user that it gave to me? That is not random!
# That becomes possible because computers are unable to poduce truly random numbers. When we ask a computer to generate a random number, it will in fact generate a "pseudo random" number. The number will be randon in the sanse that it will be some number between, for example, 0 and 1 if we ask for a uniform random distribution or a number near 0 if we aks for a Gaussian distribution with mean 0. But the sequence of pseudo-random numbers that a compujter generates will depend on its **seed**: if you know the seed you know all the numbers that are "randomely" drawn.
# You can read more about pseudorandom number generation in this wikipedia article https://en.wikipedia.org/wiki/Pseudorandom_number_generator
# Fill in the empty cells below with code, as directed.

# %%
import os
import sys

# you can use the numpy library for random number generation: 
# http://docs.scipy.org/doc/numpy/reference/routines.random.html

import numpy as np

# %% [markdown]
# THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# give numpy as seed for this code to be reproducible
# (no points if this is wrong)
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
np.random.seed(10)

# %% [markdown]
# 1. Generate random distributions. use the function
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html
# to generate 100 2-dimensional random datapoints in a gaussian distribution
# call the array ReprRand

# %%
for i in range(100):
    ReprRand = np.random.randn(2,100)

# %%
ReprRand
# Out:
# array([[ 0.66295773,  0.05190831, -0.05950402,  0.81412283, -1.52628466,
#         -1.303466  , -0.34763353,  0.66097729, -0.8827468 ,  0.17504985,
#         -1.31720584, -0.27344736, -1.80145413, -2.16217363,  0.56490149,
#          0.78558133, -0.07290898,  0.24156956,  0.85536776, -1.14644123,
#         -0.04700094, -0.90166687,  1.08288379, -1.80531286, -0.66332405,
#         -1.98126962,  2.36995504,  0.00538264,  0.2779331 , -1.09856091,
#          0.49804385,  0.89139345,  1.36755197,  1.05522856, -0.16988554,
#         -0.1894174 ,  1.02228256,  0.89205874,  0.85660948, -0.28282355,
#         -0.59900231, -0.90972547,  0.79294727, -0.44941846,  0.80176609,
#          0.75435152,  1.74246776,  1.80538539,  0.73847747, -0.67513126,
#         -1.73966518,  1.47091186,  0.46084591,  1.17330028,  0.75444531,
#         -1.09363353,  0.42853958, -1.73170151,  0.70636473, -0.20779727,
#          0.52613559, -0.20633783,  0.26845688,  0.68427061,  0.38059444,
#          1.00053414, -0.54004818,  0.32840835,  1.16398257,  0.32069168,
#         -1.62704669, -0.45868114, -0.20479654, -0.02927879, -0.60246173,
#          0.9640093 ,  1.23375107,  1.66508171, -0.04449231,  0.95774299,
#          0.76805023,  0.52732638, -0.61729493,  0.47041255, -0.86521326,
#         -2.38985246,  0.84732164,  0.32872657, -1.18446564,  0.00968237,
#         -1.41983687, -0.50961864, -0.09532164, -0.82942594, -0.41810213,
#         -0.19476968,  0.07901397, -0.04092846,  1.02504712, -0.79595829],
#        [-0.74269662,  2.6906616 , -0.2225639 , -1.57993263, -0.10434498,
#          0.95776054,  0.18294846, -0.62157777, -1.93794573,  2.00309946,
#         -0.11987798,  1.40396187,  1.32635283,  1.0530927 , -0.09675241,
#         -0.38782507,  0.76518377, -0.45943927, -1.81982297,  0.73780706,
#         -0.13637199,  0.95007055, -0.31457953,  0.39428082,  0.88282749,
#          0.02848054,  1.32121597,  1.19820398, -0.92044112,  0.4317152 ,
#          0.47741766,  1.66682942,  2.24569562, -1.26117933, -0.22903045,
#          1.37351708,  0.97464914, -0.61522546, -0.18597221,  0.35709137,
#          0.57267155,  0.21901818, -0.03771835,  0.33929333, -0.86262676,
#         -1.62645352, -2.08915652, -0.45947821, -2.51544584,  0.43713158,
#         -1.05966693, -0.09122488, -0.68305729,  0.48204904, -0.08845308,
#         -0.49420977, -0.77181068,  1.59988469, -0.76199704,  0.20938239,
#         -0.60804141, -1.25484018, -0.59186105, -3.6877226 ,  0.77444243,
#         -0.53184424, -0.19795824,  0.29505037,  1.0152601 , -1.03916563,
#          1.33063005, -0.35973636, -1.28473711,  0.43319713,  0.79120784,
#         -0.31145191, -1.8968748 ,  0.69777972,  0.56190113, -0.55664351,
#          0.17485226,  0.27696249,  1.31792121,  0.72298073, -0.22669521,
#          0.78065626,  0.59774211,  0.95771642, -0.04943872,  1.62208532,
#         -0.59082499,  0.20141839,  0.54389428, -1.33989897, -0.71701289,
#         -0.6906338 , -0.56059728,  0.82715097, -0.38584486, -0.40316037]])

# %%
ReprRand.shape
# Out:
# (2, 100)

# %% [markdown]
# 2.use the same function to generate 50 more random 2x100 numpy arrays and store them in ReprRandAll, all with different mean.
# np.random.randn creates a distribution with mean 0 and standard deviation 1 by default.
# To obtain a gaussian distribution with a mean different than 1 using np.random.randn you must add your new mean (it is explained in the dunction documentation for which I already gave you the link)
# If you want to change the standard deviation (sigma) as well you multiply the distribution by the new sigma.
# You can do it in a for loop. The first line of code I included generates an array of zeros that you can fill in with your new numbers.

# %%
ReprRandAll = np.zeros((50, 2, 100))
for i in range(50):
    ReprRandAll[i] = np.random.randint(1,50) * np.random.randn(2,100) + np.random.randint(1,50)

# %%
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %%
ReprRandAll
# Out:
# array([[[ 28.36063097,  21.32387643,  25.83322928, ...,  21.25314303,
#           26.18452202,  17.56646352],
#         [ 28.82652304,  25.97048193,  27.61039034, ...,  23.89621483,
#           30.50705042,  24.70743212]],
#
#        [[-31.51517604,   9.72896657, -32.87253073, ...,  29.08080743,
#            1.98530766, -62.36650555],
#         [  1.12021029,  10.92687332, -22.07920985, ..., -12.03914002,
#           12.36209276,  -9.85438025]],
#
#        [[ 41.12081312,  30.30687529,  61.22470215, ...,  77.74910492,
#           39.18049776,  49.60367013],
#         [ 12.9283028 ,   8.12870103,  24.34208182, ...,  46.41208588,
#           77.63963028,  51.69122899]],
#
#        ...,
#        [[ 34.39151229,  28.91439948,  65.4504264 , ...,  33.73620175,
#           28.22245961,  35.03594306],
#         [ 37.2549692 ,  18.39102957,  19.45530858, ...,  38.89744077,
#           13.49160983,  22.14556534]],
#
#        [[ 24.87559985,  29.79132841,  28.59105083, ...,   5.92888219,
#           23.07252314,  31.90236766],
#         [  5.96476799,   9.5701344 ,   9.28910041, ...,  20.309273  ,
#           33.7674047 ,  32.5603714 ]],
#
#        [[ 18.5138744 ,   7.1602872 ,   2.95551951, ...,  17.02315159,
#           21.57069619,   1.80705651],
#         [  7.13845505,  -6.06145859,  17.56751482, ...,  10.88721964,
#            8.30018901,  14.36867243]]])

# %% [markdown]
# 3.now plot them:
# you can use the matplotlib library, and the function scatter(), but that would plot everything in the same color unless you ask it not to. For convenience, let's use the function plot() which by default plots lines, and tell it to plot points (in addition plot is actually more efficient, so if you have a large dataset you may want to consider using plot with points for it anyways)
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
# http://matplotlib.org/users/pyplot_tutorial.html

# %%
import pylab as pl
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

for i in range(len(ReprRandAll)):
    for j in range(100):
        pl.plot(ReprRandAll[i][0][j],ReprRandAll[i][1][j],'o')

pl.xlabel('Distribution across X axis')
pl.ylabel('Distribution across Y axis')
pl.title('Scatter Plot showing the Random Distribution of Numbers')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Challenge
# It is easier to give the same mean and standard deviation to each dimension. Can you give two different values for the mean along the x- and the mean along the y- axis for each of the 50 distributions if you have not done so? If you are an experienced coder, can you do it in a single line?

# %%
import pylab as pl
import pandas as pd
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

for i in range(len(ReprRandAll)):
    for j in range(100):
        pl.plot(np.random.randint(1,25)*ReprRandAll[i][0][j]+np.random.randint(1,50),np.random.randint(1,25)*ReprRandAll[i][1][j]+np.random.randint(1,50),'o')

pl.xlabel('Distribution across X axis')
pl.ylabel('Distribution across Y axis')
pl.title('Scatter Plot showing Random distribution of numbers with variable mean and standard deviation')
# Out:
# Populating the interactive namespace from numpy and matplotlib
