# %%
from __future__ import print_function
__author__ = "Isha Chaturvedi, CUSP NYU 2017"

# %%
import os
import pandas as pd
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Checking if DFDATA exists
dfdata = os.getenv('DFDATA')
dfdata
# Out:
# '/gws/open/NYCOpenData/nycopendata/data'

# %%
#Dataset Location is from http://urbanprofiler.cloudapp.net/datasets
file_csv = '/g3vh-kbnw/1414246045/g3vh-kbnw'
#Reading CSV file
df=pd.read_csv(dfdata + file_csv)

# %%
#Display Top few rows
df.head()
# Out:
#   JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0  CSD 01 Manhattan                  11             4            0.36
# 1  CSD 02 Manhattan                 124            70            0.56
# 2  CSD 03 Manhattan                  38            26            0.68
# 3  CSD 04 Manhattan                  20            13            0.65
# 4  CSD 05 Manhattan                   7             4            0.57
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0           7          0.64                     0                       0
# 1          54          0.44                     0                       0
# 2          12          0.32                     0                       0
# 3           7          0.35                     0                       0
# 4           3          0.43                     0                       0
#
#    COUNT GENDER TOTAL  PERCENT GENDER TOTAL               ...                 \
# ...

# %%
# two numerical columns that are picked up to plot the scattor plot
x_column, y_column = 'PERCENT FEMALE', 'PERCENT MALE'

# 5. Remove all the numberical columns except the 'PERCENT FEMALE' & 'PERCENT MALE' column
dfnew = df.drop([
        column for column in df.columns 
        if column not in [x_column, y_column]
], axis=1).dropna(how='any')

# 6. Reduced dataframe
dfnew.head()
# Out:
#    PERCENT FEMALE  PERCENT MALE
# 0            0.36          0.64
# 1            0.56          0.44
# 2            0.68          0.32
# 3            0.65          0.35
# 4            0.57          0.43

# %%
#Rendering the entire table
dfnew
# Out:
#     PERCENT FEMALE  PERCENT MALE
# 0             0.36          0.64
# 1             0.56          0.44
# 2             0.68          0.32
# 3             0.65          0.35
# 4             0.57          0.43
# 5             0.44          0.56
# 6             0.54          0.46
# 7             0.94          0.06
# 8             0.59          0.41
# 9             0.58          0.42
# 10            0.59          0.41
# 11            0.73          0.27
# 12            1.00          0.00
# 13            0.72          0.28
# 14            0.81          0.19
# 15            0.00          0.00
# 16            0.75          0.25
# 17            0.74          0.26
# 18            0.00          0.00
# 19            0.77          0.23
# 20            0.55          0.45
# 21            0.70          0.30
# 22            0.00          0.00
# 23            0.50          0.50
# 24            0.50          0.50
# 25            0.00          1.00
# 26            0.33          0.68
# ...

# %%
#Plotting the scatter plot between the 'PERCENT FEMALE' & 'PERCENT MALE' columns for Demographic statistics broken down by school districts
dfnew.plot(x_column, y_column, kind='scatter')

pl.title('Scatter plot showing Percent Females versus Percent Males for NYC Demographic statistics broken down by school districts', y = 1.1)

pl.xlabel('Percent Female')
pl.ylabel('Percent Male')
pl.xlim([0, 1])
pl.ylim([0, 1])

#Setting the caption for the Figure
figtext(.02, -0.05, "Figure 1 : This plot shows the percent of females versus of percent of males in the school across the NYC districts.")

pl.show()
